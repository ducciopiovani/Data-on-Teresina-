# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
f1 = pd.read_csv('flows_double_0.026.txt',sep='\t',header=None)
f2 = pd.read_csv('flows_double_0.065.txt',sep='\t',header=None)

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(f2,cmap='hot')

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(f,cmap='hot')

# %%
fe = pd.read_csv('../extendedradiation/flows_0.000.txt',sep='\t',header=None)

# %%
fe.head()
# Out:
#         0         1         2          3         4         5         6   \
# 0  355.406   124.649   44.8922   113.8700   34.5952   86.6138   33.2322
# 1  438.139   238.838   22.1082    75.3517   27.4032   54.1672   21.0118
# 2  307.199   236.974  186.8810    43.7181   10.9690   33.8226   14.2659
# 3  901.698   374.172    0.0000  1857.0200  421.1060  165.1320   81.1645
# 4  154.669  1121.000   47.1430   581.9910  636.0960   95.7090  227.4990
#
#          7          8          9  ...        55        56       57        58  \
# 0   4.66682    5.41330    4.48777 ...   1.90798   6.70665  29.7296   55.7975
# 1   3.57822    4.98526    2.81858 ...   1.14209   4.33856  16.8459   36.0176
# 2   2.21244    2.61668    2.98386 ...   1.32505   3.89749  20.9755   51.1845
# 3  37.03090  169.57700  148.91100 ...  11.46900  28.96820  81.6861  182.1430
# 4  66.62480   68.15470   15.23210 ...   4.15082   9.86116  26.0404   69.7665
#
#          59        60        61        62         63  64
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(fe,cmap='hot')

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(np.abs(fe - f2),cmap='hot',ax=ax)

# %%
fe.head()
# Out:
#         0         1         2          3         4         5         6   \
# 0  355.406   124.649   44.8922   113.8700   34.5952   86.6138   33.2322
# 1  438.139   238.838   22.1082    75.3517   27.4032   54.1672   21.0118
# 2  307.199   236.974  186.8810    43.7181   10.9690   33.8226   14.2659
# 3  901.698   374.172    0.0000  1857.0200  421.1060  165.1320   81.1645
# 4  154.669  1121.000   47.1430   581.9910  636.0960   95.7090  227.4990
#
#          7          8          9  ...        55        56       57        58  \
# 0   4.66682    5.41330    4.48777 ...   1.90798   6.70665  29.7296   55.7975
# 1   3.57822    4.98526    2.81858 ...   1.14209   4.33856  16.8459   36.0176
# 2   2.21244    2.61668    2.98386 ...   1.32505   3.89749  20.9755   51.1845
# 3  37.03090  169.57700  148.91100 ...  11.46900  28.96820  81.6861  182.1430
# 4  66.62480   68.15470   15.23210 ...   4.15082   9.86116  26.0404   69.7665
#
#          59        60        61        62         63  64
# ...

# %%
f2.head()
# Out:
#          0         1         2          3         4         5         6   \
# 0   679.467   77.5695   24.3950    76.4825   24.8396   52.6262   21.7680
# 1   382.553  208.1030   33.3978    83.0233   48.3999   89.3422   31.3716
# 2   319.643   88.7320  115.3280    68.3409   25.0804   67.2328   29.1991
# 3  1751.490  385.5180  119.4440  3415.8300  270.5360  199.3230  109.3180
# 4  1195.350  472.2770   92.1134   568.5010  630.3210  207.5570  168.1290
#
#          7         8          9  ...        55       56       57        58  \
# 0   3.54928   3.13537    3.30312 ...   1.36336  3.13375  30.2080   42.3749
# 1   5.65734   5.97963    3.12404 ...   1.31228  3.06973  29.5909   52.1469
# 2   4.33270   3.76819    7.98938 ...   3.29762  6.23686  60.1206  116.7230
# 3  48.46830  79.65170  136.36400 ...  18.61780  8.94591  58.4237  235.3610
# 4  50.47030  49.37470   43.41720 ...   5.20175  4.31489  16.7424   67.4911
#
#          59        60        61        62        63  64
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.heatmap(np.abs(fe - f2) / (fe + 1),vmax=5,cmap='hot')

# %%
Ils
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-60-a83c901ee578> in <module>()
# ----> 1 Ils
#
# NameError: name 'Ils' is not defined

# %%
ls
# Out:
# P_d_double.txt                      employment_fraction_neighbours.cpp
# Pbus_brt.txt                        flows_double_0.026.txt
# Pbus_bus.txt                        flows_double_0.065.txt
# Pe_bus_5.00.txt                     functions_Double.cpp
# Pe_car_bus_5.00.txt                 functions_Double.h
# Untitled.ipynb                      indicators_brt_double.txt
# a.out*                              likelihood_calibration_double.cpp
# double_constrained_model.cpp        soersen_calibration_double.cpp

# %%
Si  = pd.read_csv('../SoersenIndexData/Double_Soersen_Index.csv',sep=',',header=None)

# %%
plt.plot(Si[0],Si[1])

# %%
Si  = pd.read_csv('../SoersenIndexData/Double_Soersen_Index.csv',sep=',',header=None)
