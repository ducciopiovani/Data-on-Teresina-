# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
cp ../single_constrained_journey_to_work/P_d_single.txt .

# %%
Ps = pd.read_csv('P_d_single.txt',sep='\t')
Pd = pd.read_csv('P_d_double.txt',sep='\t')
Pe = pd.read_csv('Pe_car_bus_5.00.txt',sep='\t',header=None)
Pe.columns = ['time','P']
P = pd.DataFrame()
P['Pe'] = Pe.P
P['S'] = Ps.P
P['D'] = Pd.P
P['time']=Pd.time
P.plot('time',['Pe','S','D'])
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.scatter(P.Pe,P.S,c='r')
plt.scatter(P.Pe,P.D,c='b')
print np.corrcoef(P.Pe,P.D)[0][1]
print np.corrcoef(P.Pe,P.S)[0][1]
# Out:
# <img src="data:image/png;base64,...">
# 0.912646346789
# 0.917887014704

# %%
Ibus = pd.read_csv('indicators_bus_double.txt',sep='\t')
Ibus.set_index('Label',inplace=True) 
Ibrt = pd.read_csv('indicators_brt_double.txt',sep='\t')
Ibrt.set_index('Label',inplace=True)

# %%
(Ibrt / Ibus).plot(subplots=True)
#,layout=(2,2)
# Out:
# <img src="data:image/png;base64,...">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x120ffaf90>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1212837d0>], dtype=object)

# %%
(Ibrt / Ibus).plot(subplots=True)
# Out:
# <img src="data:image/png;base64,...">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ffc2bd0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x120ef3410>], dtype=object)

# %%
f , subs = plt.subplots(4)
plt.legend()
for n,c in enumerate(Ibus.columns):
    subs[n].set_title(c)
    subs[n].plot(Ibus[c],'r',label='bus')
    subs[n].plot(Ibrt[c],'b',label='brt')
# Out:
# <img src="data:image/png;base64,...">
