# %%
# %matplotlib inline

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
Abrt = pd.read_csv('../accessibility/accessibility_brt_extended.txt',sep='\t')
Abus = pd.read_csv('../accessibility/accessibility_bus_extended.txt',sep='\t')
Abrt['A3'].plot()
Abus['A3'].plot()

# %%
Abrt = pd.read_csv('../accessibility/accessibility_brt_double.txt',sep='\t')
Abus = pd.read_csv('../accessibility/accessibility_bus_extended.txt',sep='\t')
Abrt['A3'].plot()
Abus['A3'].plot()
